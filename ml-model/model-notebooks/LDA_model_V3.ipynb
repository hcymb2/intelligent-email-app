# %%
import numpy as np
import pandas as pd
import re, gensim, spacy, nltk

from nltk.corpus import stopwords

# Sklearn
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from pprint import pprint


# Plotting tools
import pyLDAvis
import pyLDAvis.gensim_models  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\pylab\config.py:70: DeprecationWarning: InlineBackend._figure_formats_changed is deprecated in traitlets 4.1: use @observe and @unobserve instead.
#   def _figure_formats_changed(self, name, old, new):

# %%
# NLTK Stop words
# stop_words = stopwords.words('english')

nltk.download('words')
words = set(nltk.corpus.words.words())
# Out:
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
email_dataset = pd.read_csv("../../csv-dataset/custom_email_dataset.csv") 
email_dataset.head()
# Out:
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                    Date_time                                     From  \
# 0  2021-04-16 11:34:34+00:00  Quincy Larson <quincy@freecodecamp.org>
# 1  2021-04-09 19:15:54+00:00  Quincy Larson <quincy@freecodecamp.org>
# 2  2021-04-02 14:59:32+00:00  Quincy Larson <quincy@freecodecamp.org>
# 3  2021-03-26 17:00:08+00:00  Quincy Larson <quincy@freecodecamp.org>
# 4  2021-03-05 14:37:38+00:00  Quincy Larson <quincy@freecodecamp.org>
#
#                     To                                            Subject  \
# 0  malvisbid@gmail.com  Learn how to code video games [free 7-hour Uni...
# 1  malvisbid@gmail.com  Two free Python courses for you this week – Dj...
# 2  malvisbid@gmail.com  Learn to code APIs using Node.js [free 8-hour ...
# 3  malvisbid@gmail.com  40 JavaScript project ideas so you can learn b...
# 4  malvisbid@gmail.com  Learn AWS cloud basics [free 5-hour DevOps cou...
#
#                                         Message_body
# 0  Here are this week's five links that are worth...
# 1  Here are this week's five links that are worth...
# 2  Here are this week's five links that are worth...
# 3  Here are this week's five links that are worth...
# 4  Here are this week's five links that are worth...

# %%
email_bodies=email_dataset.drop(['Date_time','From','To','Subject'], axis = 1)
email_bodies.head()
# Out:
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                         Message_body
# 0  Here are this week's five links that are worth...
# 1  Here are this week's five links that are worth...
# 2  Here are this week's five links that are worth...
# 3  Here are this week's five links that are worth...
# 4  Here are this week's five links that are worth...

# %%
# Convert to list
data = email_bodies.values.tolist()
pprint(data[0])
# Out:
# ["Here are this week's five links that are worth your time:\r\n"
#  '\r\n'
#  '1. Building video games can be just as much fun as playing them. And this '
#  'in-depth Unity 3D course for beginners will show you how to get started as a '
#  "game developer. You'll learn how to install Unity, program game physics, "
#  'animate your characters, code your enemy AI, and more. (7 hour YouTube '
#  'course): '
#  'https://www.freecodecamp.org/news/game-development-for-beginners-unity-course/\r\n'
#  '\r\n'
#  "2. As of 2021, more than 40% of all websites use WordPress. It's a "
#  'relatively easy tool for building blogs, ecommerce sites, and more elaborate '
#  'applications as well. This free course will show you how to host a WordPress '
#  'site on the web, add custom features through plugins, and design it to look '
#  'however you want. (2 hour YouTube course): '
#  'https://www.freecodecamp.org/news/how-to-make-a-website-with-wordpress/\r\n'
#  '\r\n'
#  '3. You may have heard about the branch of science called Game Theory. This '
#  'tutorial will show you how Evolutionary Game Theory works in an ecosystem, '
#  'with simulations, Python code, and some good old-fashioned math. (10 minute '
#  'read): '
#  'https://www.freecodecamp.org/news/introduction-to-evolutionary-game-theory/\r\n'
#  '\r\n'
#  '4. Kubernetes is a powerful DevOps tool for managing software in the cloud. '
#  "If you haven't heard of it yet, it's only 6 years old. This said, I searched "
#  'Indeed and found 25,000 job openings that mentioned Kubernetes, so a lot of '
#  "companies are using it. Sergio recently passed the Linux Foundation's exam "
#  'to become a Certified Kubernetes Application Developer, and he shares tips '
#  'for how you can do the same. (45 minute read): '
#  'https://www.freecodecamp.org/news/how-to-become-a-certified-kubernetes-application-developer/\r\n'
#  '\r\n'
#  '5. Dhawal just updated his massive list of 450 courses from Ivy League '
#  'universities that you can take for free online. (browsable list): '
#  'https://www.freecodecamp.org/news/ivy-league-free-online-courses-a0d7ae675869/\r\n'
#  '\r\n'
#  "And a quick update: we're making steady progress on freeCodeCamp's Data "
#  'Science Curriculum Expansion. These 12 new certifications will teach '
#  'advanced mathematics, computer science, and machine learning. So far, more '
#  'than 1,900 people have donated to ensure that our nonprofit has the budget '
#  'we need to hire experienced teachers. You can learn more and get involved '
#  'here: '
#  'https://www.freecodecamp.org/news/building-a-data-science-curriculum-with-advanced-math-and-machine-learning/\r\n'
#  '\r\n'
#  '\r\n'
#  'Quote of the Week: “I’m obsessed with finishing as a skill. Over the years, '
#  'I’ve realized that so many of the good things that have come my way are '
#  'because I was able to finish what I started.” – Derek Yu, Game Developer and '
#  'creator of Spelunky\r\n'
#  '\r\n'
#  '\r\n'
#  'Happy coding.\r\n'
#  '\r\n'
#  '- Quincy Larson\r\n'
#  '\r\n'
#  'Teacher at https://www.freecodecamp.org\r\n'
#  'I share useful things on Twitter at https://www.twitter.com/ossia\r\n'
#  '\r\n'
#  "If these emails aren't worth your time, you can turn them off: "
#  'https://www.freecodecamp.org/ue/YSTttLxqo1nneGosGnvB\r\n']
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Using regex expressions to get rid of distractions
# each document is in a list, convert to string
data = [''.join(str(sent)) for sent in data]
data
# Out:
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# s://medium.freecodecamp.org/8bf4396804e0\\r\\n\\r\\n4. Allan didn\\\'t like his corporate job, so he spent his nights and weekends at the public library learning to code through freeCodeCamp. 2 years ago he got his first developer job, and now he\\\'s launching his own company. He just posted his story on our forum (3 minute read): https://www.freecodecamp.org/forum/t/264857\\r\\n\\r\\n5. In this week\\\'s episode of the freeCodeCamp Podcast, Abbey interviews Tracy Lee about how she became a developer, her love of JavaScript frameworks, and what it\\\'s like to be a developer evangelist (1 hour listen in your podcast player on your phone, or here in your browser): https://podcast.freecodecamp.org\\r\\n\\r\\nQuote of the Week: "The only truly secure system is one that is powered off, cast in a block of concrete and sealed in a lead-lined room with armed guards." - Gene Spafford\\r\\n\\r\\n\\r\\nfreeCodeCamp is a donor-supported nonprofit. Help the community reach our goal of 10,000 monthly supporters. (We\\\'re already 45% of the way there!) Become a supporter at: https://donate.freecodecamp.org\\r\\n\\r\\n\\r\\nHappy coding!\\r\\n\\r\\n- Quincy Larson\\r\\n\\r\\nTeacher at freeCodeCamp.org\\r\\n\\r\\n\\r\\nIf these emails aren\\\'t worth your time, you can turn them off: https://www.freecodecamp.org/ue/YSTttLxqo1nneGosGnvB\\r\\n\\n\']',
#  '[\'Here are this week\\\'s five links that are worth your time:\\r\\n\\r\\n1. How to code like a pro - learn advanced programming concepts from a freeCodeCamp graduate who\\\'s now working as a software engineer (2 hour watch): https://www.freecodecamp.org/news/how-to-code-like-a-pro\\r\\n\\r\\n2. Learn the basics of Data Science - statistics, data visualization, and Python programming - in this free course (2 hour watch): https://www.freecodecamp.org/news/learn-the-basics-of-data-science\\r\\n\\r\\n3. Madison writes about how she went from complete beginner to software developer, and offers tips for how you can too (7 minute read): https://medium.freecodecamp.org/dd36ed08e11b\\r\\n\\r\\n4. In this week\\\'s episode of the freeCodeCamp Podcast, I interview lawyer-turned-developer Zubin Pratap. We talk about hackathons, moving to Melbourne, and leaving one promising career for another (1 hour listen in your podcast player on your phone, or here in your browser): https://podcast.freecodecamp.org\\r\\n\\r\\n5. Also, freeCodeCamp now has an Instagram account where we share photos from  the global developer community (browsable gallery): https://www.instagram.com/freecodecamp\\r\\n\\r\\nQuote of the Week: "Security is always excessive until it\\\'s not enough." - Robbie Sinclair\\r\\n\\r\\n\\r\\nfreeCodeCamp is a donor-supported nonprofit. Help the community reach our goal of 10,000 monthly supporters. (We\\\'re already 45% of the way there!) Become a supporter at: https://donate.freecodecamp.org\\r\\n\\r\\n\\r\\nHappy coding!\\r\\n\\r\\n- Quincy Larson\\r\\n\\r\\nTeacher at freeCodeCamp.org\\r\\n\\r\\n\\r\\nIf these emails aren\\\'t worth your time, you can turn them off: https://www.freecodecamp.org/ue/YSTttLxqo1nneGosGnvB\\r\\n\\n\']',
#  '[\'Here are this week\\\'s five links that are worth your time:\\r\\n\\r\\n1. How to code your own Double Dragon-style fighting game - a free Unity 3D course (5 hour watch): https://www.freecodecamp.org/news/create-a-beat-em-up-game-in-unity\\r\\n\\r\\n2. "Iâ€™m finally getting paid to do what I love!" How Franklin taught himself to code and got his first job as a front-end developer (6 minute read): https://www.freecodecamp.org/forum/t/261411\\r\\n\\r\\n3. Here are 550 free online programming and computer science courses that you can start in March (browsable list): https://medium.freecodecamp.org/d1944d6e467\\r\\n\\r\\n4. In this week\\\'s episode of the freeCodeCamp Podcast, Abbey and I talk about the history of the podcast and our upcoming interviews with developers from all around the world (50 minute listen in your phone\\\'s podcast player or here in your browser): https://podcast.freecodecamp.org\\r\\n\\r\\n5. Advanced TypeScript patterns - learn how to write statically-typed JavaScript using Ramda and currying (20 minute read): https://medium.freecodecamp.org/f747e99744ab\\r\\n\\r\\n\\r\\nQuote of the Week: "In a relatively short time we\\\'ve taken a system built to resist destruction by nuclear weapons and made it vulnerable to toasters." - Jeff Jarmoc\\r\\n\\r\\n\\r\\nfreeCodeCamp is a donor-supported nonprofit. Help the community reach our goal of 10,000 monthly supporters. (We\\\'re already 45% of the way there!) Become a supporter at: https://donate.freecodecamp.org\\r\\n\\r\\n\\r\\nHappy coding!\\r\\n\\r\\n- Quincy Larson\\r\\n\\r\\nTeacher at freeCodeCamp.org\\r\\n\\r\\n\\r\\nIf these emails aren\\\'t worth your time, you can turn them off: https://www.freecodecamp.org/ue/YSTttLxqo1nneGosGnvB\\r\\n\\n\']',
#  '[\'Here are this week\\\'s five links that are worth your time:\\r\\n\\r\\n1. How to solve algorithm challenges in job interviews - a free 4-hour course.  This is taught using Python, which is similar to JavaScript and also worth learning.  (4 hour watch): https://www.freecodecamp.org/news/python-algorithms-for-job-interviews\\r\\n\\r\\n2. The host of a popular Python podcast explains NoSQL databases and helps you get started with MongoDB (2 hour watch): https://www.freecodecamp.org/news/mongodb-quickstart-with-python\\r\\n\\r\\n3. How to write an awesome junior developer résumé in a few simple steps (7 minute read): https://medium.freecodecamp.org/316010db80ec\\r\\n\\r\\n4. How a young father from a small town in the American South taught himself to code for 2 years then got a job as a data engineer (12 minute read): https://www.freecodecamp.org/forum/t/258285\\r\\n\\r\\n5. From Zero to Deploy: How Eden created her own static website from scratch using Netlify and Gatsby, and how you can do it, too (5 minute read): https://medium.freecodecamp.org/ebca82612ffd\\r\\n\\r\\nQuote of the Week: "A computer lets you make more mistakes faster than any invention in human history - with the possible exceptions of handguns and tequila." - Mitch Ratliff\\r\\n\\r\\n\\r\\nfreeCodeCamp is a donor-supported nonprofit. Help the community reach our goal of 10,000 monthly supporters. (We\\\'re already 44% of the way there!) Become a supporter at: https://donate.freecodecamp.org\\r\\n\\r\\n\\r\\nHappy coding!\\r\\n\\r\\n- Quincy Larson\\r\\n\\r\\nTeacher at freeCodeCamp.org\\r\\n\\r\\n\\r\\nIf these emails aren\\\'t worth your time, you can turn them off: https://www.freecodecamp.org/ue/YSTttLxqo1nneGosGnvB\\r\\n\\n\']',
#  '[\'Here are this week\\\'s five links that are worth your time:\\r\\n\\r\\n1. Learn back end development with Node.js and Express using this free in-depth course (2.5 hour watch): https://www.freecodecamp.org/news/learn-express-js-in-this-complete-course\\r\\n\\r\\n2. Kevin got his first job as a web developer when he was 49 years old. He shares his advice for how you can learn to code and get a developer job, too (41 minute read): https://www.freecodecamp.org/forum/t/258707\\r\\n\\r\\n3. From ES5 to ESNext - here’s every feature added to JavaScript since 2015 (40 minute read): https://medium.freecodecamp.org/d0c255e13c6e\\r\\n\\r\\n4. How to build your own Pokémon game - the latest in freeCodeCamp\\\'s series of Harvard University GameDev lectures (2 hour watch): https://www.freecodecamp.org/news/code-your-own-pokemon-game\\r\\n\\r\\n5. An introduction to Test-Driven Development - written by a developer who spent 5 years avoiding TDD but finally embraced it (22 minute read): https://medium.freecodecamp.org/c4de6dce5c\\r\\n\\r\\nQuote of the Week: "The function of good software is to make the complex appear to be simple." - Grady Booch\\r\\n\\r\\n\\r\\nfreeCodeCamp is a donor-supported nonprofit. Help the community reach our goal of 10,000 monthly supporters. (We\\\'re already 44% of the way there!) Become a supporter at: https://donate.freecodecamp.org\\r\\n\\r\\n\\r\\nHappy coding!\\r\\n\\r\\n- Quincy Larson\\r\\n\\r\\nTeacher at freeCodeCamp.org\\r\\n\\r\\n\\r\\nIf these emails aren\\\'t worth your time, you can turn them off: https://www.freecodecamp.org/ue/YSTttLxqo1nneGosGnvB\\r\\n\\n\']',
#  '[\'Here are this week\\\'s five links that are worth your time:\\r\\n\\r\\n1. What\\\'s the difference between a library and a framework? (4 minute read): https://medium.freecodecamp.org/bd133054023f\\r\\n\\r\\n2. Learn the key machine learning concepts and how to apply them to real-life projects using PyTorch (6 hour video course): https://www.freecodecamp.org/news/applied-deep-learning-with-pytorch-full-course\\r\\n\\r\\n3. How one economics student in Europe taught himself to code for two years then got his dream job as a developer (3 minute read): https://www.freecodecamp.org/forum/t/254796\\r\\n\\r\\n4. Never feel overwhelmed at work again - how to use the MIT technique to be more productive (5 minute read): https://medium.freecodecamp.org/70d132aad0cc\\r\\n\\r\\n5. Did you know that the freeCodeCamp community has a music live stream called Code Radio? Tune in to some jazzy beats while you code (24/7 live stream): https://www.freecodecamp.org/news/code-radio\\r\\n\\r\\nQuote of the Week: "If having a coffee in the morning doesn\\\'t wake you up, try deleting a table in a production database instead." - Juozas Kaziukenas\\r\\n\\r\\n\\r\\nfreeCodeCamp is a donor-supported nonprofit. Help the community reach our goal of 10,000 monthly supporters. (We\\\'re already 44% of the way there!) Become a supporter at: https://donate.freecodecamp.org\\r\\n\\r\\n\\r\\nHappy coding!\\r\\n\\r\\n- Quincy Larson\\r\\n\\r\\nTeacher at freeCodeCamp.org\\r\\n\\r\\n\\r\\nIf these emails aren\\\'t worth your time, you can turn them off: https://www.freecodecamp.org/ue/YSTttLxqo1nneGosGnvB\\r\\n\\n\']',
#  '[\'Here are this week\\\'s five links that are worth your time:\\r\\n\\r\\n1. Python is a great programming language to learn once you feel comfortable with JavaScript. Here\\\'s Harvard\\\'s Intro to Python (2 hour watch): https://www.freecodecamp.org/news/learn-python-from-harvards-cs50\\r\\n\\r\\n2. And if you want to dig even further into Python, try our in-depth course on Python basics (4 hour watch): https://www.freecodecamp.org/news/learn-python-basics-in-depth-video-course\\r\\n\\r\\n3. How to produce your own meaningful datasets - right in SQL (7 minute read): https://medium.freecodecamp.org/394c4781a5e0\\r\\n\\r\\n4. Ursula was in her late 30s and unhappy with her career in science. Here\\\'s how she taught herself to code using freeCodeCamp for 10 months, then got a job as a developer (3 minute read): https://www.freecodecamp.org/forum/t/252499/32\\r\\n\\r\\n5. Here are 560 free online programming and computer science courses that you can start in February (browsable list): https://medium.freecodecamp.org/e621d959e64\\r\\n\\r\\nQuote of the Week: "The most amazing achievement of the computer software industry is its continuing cancellation of the steady and staggering gains made by the computer hardware industry." - Henry Petroski\\r\\n\\r\\n\\r\\nfreeCodeCamp is a donor-supported nonprofit. Help the community reach our goal of 10,000 monthly supporters. (We\\\'re already 43% of the way there!) Become a supporter at: https://donate.freecodecamp.org\\r\\n\\r\\n\\r\\nHappy coding!\\r\\n\\r\\n- Quincy Larson\\r\\n\\r\\nTeacher at freeCodeCamp.org\\r\\n\\r\\n\\r\\nIf these emails aren\\\'t worth your time, you can turn them off: https://www.freecodecamp.org/ue/YSTttLxqo1nneGosGnvB\\r\\n\\n\']',
#  '[\'Here are this week\\\'s five links that are worth your time:\\r\\n\\r\\n1. Harvard\\\'s CS50 Intro to Computer Science course is now free (and ad-free) on freeCodeCamp\\\'s YouTube channel. We\\\'re posting one new video each day and discussing them here (40 hour course): https://www.freecodecamp.org/forum/t/the-first-few-harvard-cs50-videos-are-now-live/253738\\r\\n\\r\\n2. Capture The Flag challenges are a great way to expand your cybersecurity and ethical hacking skills. Here\\\'s an in-depth walkthrough of the popular PicoCTF challenge (6 hour tutorial): https://www.freecodecamp.org/news/improve-cybersecurity-skills-with-ctfs-picoctf-walkthrough\\r\\n\\r\\n3. How Graph Data Structures work - explained visually (9 minute read): https://medium.freecodecamp.org/6d88f36ec768\\r\\n\\r\\n4. How to build your own First Person Shooter game - using Unity3D (8 hour tutorial): https://www.freecodecamp.org/news/unity-3d-first-person-shooter-game-tutorial\\r\\n\\r\\n5. Maribel\\\'s parents immigrated to the US as field workers. She was the first person in her family to graduate from college. And after years of teaching herself coding, she is now working as a software engineer. This is her story (16 minute read): https://medium.freecodecamp.org/4ae301fc02b\\r\\n\\r\\nThis weeks quote: "The Web as I envisaged it, we have not seen it yet. The future is still so much bigger than the past."\\u200a—\\u200aTim Berners-Lee (inventor of the web)\\r\\n\\r\\n\\r\\nfreeCodeCamp is a donor-supported nonprofit. Help the community reach our goal of 10,000 monthly supporters. (We\\\'re already 42% of the way there!) Become a supporter at: https://donate.freecodecamp.org/?r=e2\\r\\n\\r\\n\\r\\nHappy coding!\\r\\n\\r\\n- Quincy Larson\\r\\n\\r\\nTeacher at freeCodeCamp.org\\r\\n\\r\\n\\r\\nIf these emails aren\\\'t worth your time, you can turn them off: https://www.freecodecamp.org/ue/YSTttLxqo1nneGosGnvB\\r\\n\\n\']',
#  '[\'Here are this week\\\'s five links that are worth your time:\\r\\n\\r\\n1. How to build your own e-commerce website from scratch with React, and how to host it for free using Netlify (6 hour watch): https://www.freecodecamp.org/news/react-tutorial-ecomerce-site\\r\\n\\r\\n2. Here are 380 Ivy League courses you can take online right now for free (browsable list): https://medium.freecodecamp.org/9b3ffcbd7b8c\\r\\n\\r\\n3. How to design website layouts that work well with screen readers - so that blind people can use your website, too (7 minute read): https://medium.freecodecamp.org/347b7b06e9cc\\r\\n\\r\\n4. The story of how Vivian went from working in a Nigerian call center to landing her first job as a software developer. She used freeCodeCamp and took the 100 Days of Code Challenge. (6 minute read): https://medium.freecodecamp.org/19b01f17bca1\\r\\n\\r\\n5. Introducing: You Can Do This - a new place where you can get support during your coding journey (1 minute read): https://www.freecodecamp.org/news/you-can-do-this\\r\\n\\r\\nThis week\\\'s quote: "We can only see a short distance ahead, but we can see plenty there that needs to be done."\\u200a—\\u200aAlan Turing\\r\\n\\r\\n\\r\\nA huge thanks to the 4,140 supporters who donate to our nonprofit each month. You make all of this possible. If you\\\'re not donating yet, please consider doing so: https://donate.freecodecamp.org/?r=e\\r\\n\\r\\n\\r\\nHappy coding!\\r\\n\\r\\n- Quincy Larson\\r\\n\\r\\nTeacher at freeCodeCamp.org\\r\\n\\r\\n\\r\\nIf these emails aren\\\'t worth your time, you can turn them off: https://www.freecodecamp.org/ue/YSTttLxqo1nneGosGnvB\\r\\n\\n\']',
#  '[\'Here are this week\\\'s five links that are worth your time:\\r\\n\\r\\n1. The React Handbook - a massive free guide to building web applications with ReactJS (116 minute read): https://medium.freecodecamp.org/the-react-handbook-b71c27b0a795\\r\\n\\r\\n2. How to build your own Tetris game using Python and Pygame (2 hour watch): https://www.freecodecamp.org/news/tetris-python-tutorial-pygame\\r\\n\\r\\n3. The story of how Christina went from stay-at-home mother of 3 kids to working full time from home as a JavaScript developer (3 minute read): https://www.freecodecamp.org/forum/t/244230\\r\\n\\r\\n4. Learn MongoDB - the popular NoSQL database - by building a Node.js CRUD app from scratch (75 minute watch): https://www.freecodecamp.org/news/mongodb-crud-app\\r\\n\\r\\n5. Over the winter holiday, Angela challenged herself to build one coding project each day for 20 days. Her resulting apps are fun and elegant. (6 minute read): https://medium.freecodecamp.org/5cd4c9383f84\\r\\n\\r\\nThis week\\\'s quote: "If the automobile had followed the same development cycle as the computer, a Rolls-Royce would today cost $100, get a million miles per gallon, and explode once a year, killing everyone inside." - Robert Cringely\\r\\n\\r\\n\\r\\nfreeCodeCamp.org is a 501(c)(3) nonprofit. A huge thanks to our 4,116 supporters who donate each month to make all of this possible. For less than the price of a sandwich you can support us too: https://donate.freecodecamp.org/?r=e2\\r\\n\\r\\n\\r\\nHappy coding!\\r\\n\\r\\n- Quincy Larson\\r\\n\\r\\nTeacher at freeCodeCamp.org\\r\\n\\r\\n\\r\\nIf these emails aren\\\'t worth your time, you can turn them off: https://www.freecodecamp.org/ue/YSTttLxqo1nneGosGnvB\\r\\n\\n\']',
#  '[\'This is my final "links worth your time" list for 2018. Happy Holidays!\\r\\n\\r\\nHere are this week\\\'s five links that are worth your time:\\r\\n\\r\\n1. Learn React.js with this free 5 hour course for beginners. You\\\'ll learn about styling components, conditional rendering, state management, and more (5 hour watch): https://www.freecodecamp.org/n/jiLKNpplm\\r\\n\\r\\n2. Introducing Programmer Playing Cards - learn about programmer history while you play classic card games like Poker, Blackjack, and Solitaire (4 minute read): https://medium.freecodecamp.org/d3eeeffe9a11\\r\\n\\r\\n3. Here are the results of the freeCodeCamp 2018 New Coder Survey. 31,000 respondents told us about how they\\\'re learning to code and getting their first developer jobs (6 minute read): https://medium.freecodecamp.org/e10feb9ed419\\r\\n\\r\\n4. Learn how to build your own Android app. This free course will show you how to use Android Studio, Firebase, Java, and more to build your own clone of WhatsApp messenger (5 hour watch): https://www.freecodecamp.org/n/ksLpiub87\\r\\n\\r\\n5. How Phoebe went from stay-at-home mom to working as a front end web developer in less than a year by studying freeCodeCamp (8 minute read): https://medium.freecodecamp.org/39724046692a\\r\\n\\r\\n\\r\\nHappy coding!\\r\\n\\r\\n- Quincy Larson\\r\\n\\r\\nTeacher at freeCodeCamp.org\\r\\n\\r\\n\\r\\nIf these emails aren\\\'t worth your time, you can turn them off: https://www.freecodecamp.org/ue/YSTttLxqo1nneGosGnvB\\r\\n\\n\']',
#  '["Here are this week\'s five links that are worth your time:\\r\\n\\r\\n1. Learn JavaScript - our free 134-part video course for beginners (3.5 hour watch): https://www.freecodecamp.org/n/j4Va5cR1p\\r\\n\\r\\n2. Learn penetration testing, from beginner to advanced. We cover Ethical Hacking concepts like CSRF, XSS, Brute Force Attacks, SQL Injection, and more in this free video course (3 hour watch): https://www.freecodecamp.org/n/pena5cR1p\\r\\n\\r\\n3. Amazingly, 1 out of every 200 developers is completely blind. Here\'s how freeCodeCamp is helping teach even more blind people how to code (4 minute read): https://medium.freecodecamp.org/c47c68d4a237\\r\\n\\r\\n4. Even in an active war zones in Afghanistan, thousands of people are coming together to learn to code and expand their careers using freeCodeCamp (4 minute read): https://medium.freecodecamp.org/d553719579e\\r\\n\\r\\n5. Here are 670 free online programming and computer science courses you can start in December (browsable list): https://medium.freecodecamp.org/a90149ac6de4\\r\\n\\r\\n\\r\\nfreeCodeCamp is a tiny nonprofit with a big mission: to provide everyone with a world-class technology education for free. Your tax-deductible donations help us create more learning tools and resources. Become a supporter today at https://donate.freecodecamp.org\\r\\n\\r\\n\\r\\nHappy coding!\\r\\n\\r\\n- Quincy Larson\\r\\n\\r\\nTeacher at freeCodeCamp.org\\r\\n\\r\\n\\r\\nIf these emails aren\'t worth your time, you can turn them off: https://www.freecodecamp.org/ue/YSTttLxqo1nneGosGnvB\\r\\n\\n"]']

# %%
# Remove non alphanumeric and underscore values
data = [re.sub(r'[^\w]', ' ', sent) for sent in data]
data[0]
# Out:
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# '  Here are this week s five links that are worth your time  r n r n1  Building video games can be just as much fun as playing them  And this in depth Unity 3D course for beginners will show you how to get started as a game developer  You ll learn how to install Unity  program game physics  animate your characters  code your enemy AI  and more   7 hour YouTube course   https   www freecodecamp org news game development for beginners unity course  r n r n2  As of 2021  more than 40  of all websites use WordPress  It s a relatively easy tool for building blogs  ecommerce sites  and more elaborate applications as well  This free course will show you how to host a WordPress site on the web  add custom features through plugins  and design it to look however you want   2 hour YouTube course   https   www freecodecamp org news how to make a website with wordpress  r n r n3  You may have heard about the branch of science called Game Theory  This tutorial will show you how Evolutionary Game Theory works in an ecosystem  with simulations  Python code  and some good old fashioned math   10 minute read   https   www freecodecamp org news introduction to evolutionary game theory  r n r n4  Kubernetes is a powerful DevOps tool for managing software in the cloud  If you haven t heard of it yet  it s only 6 years old  This said  I searched Indeed and found 25 000 job openings that mentioned Kubernetes  so a lot of companies are using it  Sergio recently passed the Linux Foundation s exam to become a Certified Kubernetes Application Developer  and he shares tips for how you can do the same   45 minute read   https   www freecodecamp org news how to become a certified kubernetes application developer  r n r n5  Dhawal just updated his massive list of 450 courses from Ivy League universities that you can take for free online   browsable list   https   www freecodecamp org news ivy league free online courses a0d7ae675869  r n r nAnd a quick update  we re making steady progress on freeCodeCamp s Data Science Curriculum Expansion  These 12 new certifications will teach advanced mathematics  computer science  and machine learning  So far  more than 1 900 people have donated to ensure that our nonprofit has the budget we need to hire experienced teachers  You can learn more and get involved here  https   www freecodecamp org news building a data science curriculum with advanced math and machine learning  r n r n r nQuote of the Week   I m obsessed with finishing as a skill  Over the years  I ve realized that so many of the good things that have come my way are because I was able to finish what I started     Derek Yu  Game Developer and creator of Spelunky r n r n r nHappy coding  r n r n  Quincy Larson r n r nTeacher at https   www freecodecamp org r nI share useful things on Twitter at https   www twitter com ossia r n r nIf these emails aren t worth your time  you can turn them off  https   www freecodecamp org ue YSTttLxqo1nneGosGnvB r n  '

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))
pprint(data_words)
# Out:
#   'ue',
#   'ystttlxqo',
#   'nnegosgnvb'],
#  ['here',
#   'are',
#   'this',
#   'week',
#   'five',
#   'links',
#   'that',
#   'are',
#   'worth',
#   'your',
#   'time',
#   'learn',
#   'back',
#   'end',
#   'development',
#   'with',
#   'node',
#   'js',
#   'and',
#   'express',
#   'using',
#   'this',
#   'free',
#   'in',
#   'depth',
#   'course',
#   'hour',
#   'watch',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'news',
#   'learn',
#   'express',
#   'js',
#   'in',
#   'this',
#   'complete',
#   'course',
#   'kevin',
#   'got',
#   'his',
#   'first',
#   'job',
#   'as',
#   'web',
#   'developer',
#   'when',
#   'he',
#   'was',
#   'years',
#   'old',
#   'he',
#   'shares',
#   'his',
#   'advice',
#   'for',
#   'how',
#   'you',
#   'can',
#   'learn',
#   'to',
#   'code',
#   'and',
#   'get',
#   'developer',
#   'job',
#   'too',
#   'minute',
#   'read',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'forum',
#   'from',
#   'es',
#   'to',
#   'esnext',
#   'here',
#   'every',
#   'feature',
#   'added',
#   'to',
#   'javascript',
#   'since',
#   'minute',
#   'read',
#   'https',
#   'medium',
#   'freecodecamp',
#   'org',
#   'how',
#   'to',
#   'build',
#   'your',
#   'own',
#   'pokemon',
#   'game',
#   'the',
#   'latest',
#   'in',
#   'freecodecamp',
#   'series',
#   'of',
#   'harvard',
#   'university',
#   'gamedev',
#   'lectures',
#   'hour',
#   'watch',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'news',
#   'code',
#   'your',
#   'own',
#   'pokemon',
#   'game',
#   'an',
#   'introduction',
#   'to',
#   'test',
#   'driven',
#   'development',
#   'written',
#   'by',
#   'developer',
#   'who',
#   'spent',
#   'years',
#   'avoiding',
#   'tdd',
#   'but',
#   'finally',
#   'embraced',
#   'it',
#   'minute',
#   'read',
#   'https',
#   'medium',
#   'freecodecamp',
#   'org',
#   'de',
#   'dce',
#   'nquote',
#   'of',
#   'the',
#   'week',
#   'the',
#   'function',
#   'of',
#   'good',
#   'software',
#   'is',
#   'to',
#   'make',
#   'the',
#   'complex',
#   'appear',
#   'to',
#   'be',
#   'simple',
#   'grady',
#   'booch',
#   'nfreecodecamp',
#   'is',
#   'donor',
#   'supported',
#   'nonprofit',
#   'help',
#   'the',
#   'community',
#   'reach',
#   'our',
#   'goal',
#   'of',
#   'monthly',
#   'supporters',
#   'we',
#   're',
#   'already',
#   'of',
#   'the',
#   'way',
#   'there',
#   'become',
#   'supporter',
#   'at',
#   'https',
#   'donate',
#   'freecodecamp',
#   'org',
#   'nhappy',
#   'coding',
#   'quincy',
#   'larson',
#   'nteacher',
#   'at',
#   'freecodecamp',
#   'org',
#   'nif',
#   'these',
#   'emails',
#   'aren',
#   'worth',
#   'your',
#   'time',
#   'you',
#   'can',
#   'turn',
#   'them',
#   'off',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'ue',
#   'ystttlxqo',
#   'nnegosgnvb'],
#  ['here',
#   'are',
#   'this',
#   'week',
#   'five',
#   'links',
#   'that',
#   'are',
#   'worth',
#   'your',
#   'time',
#   'what',
#   'the',
#   'difference',
#   'between',
#   'library',
#   'and',
#   'framework',
#   'minute',
#   'read',
#   'https',
#   'medium',
#   'freecodecamp',
#   'org',
#   'bd',
#   'learn',
#   'the',
#   'key',
#   'machine',
#   'learning',
#   'concepts',
#   'and',
#   'how',
#   'to',
#   'apply',
#   'them',
#   'to',
#   'real',
#   'life',
#   'projects',
#   'using',
#   'pytorch',
#   'hour',
#   'video',
#   'course',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'news',
#   'applied',
#   'deep',
#   'learning',
#   'with',
#   'pytorch',
#   'full',
#   'course',
#   'how',
#   'one',
#   'economics',
#   'student',
#   'in',
#   'europe',
#   'taught',
#   'himself',
#   'to',
#   'code',
#   'for',
#   'two',
#   'years',
#   'then',
#   'got',
#   'his',
#   'dream',
#   'job',
#   'as',
#   'developer',
#   'minute',
#   'read',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'forum',
#   'never',
#   'feel',
#   'overwhelmed',
#   'at',
#   'work',
#   'again',
#   'how',
#   'to',
#   'use',
#   'the',
#   'mit',
#   'technique',
#   'to',
#   'be',
#   'more',
#   'productive',
#   'minute',
#   'read',
#   'https',
#   'medium',
#   'freecodecamp',
#   'org',
#   'aad',
#   'cc',
#   'did',
#   'you',
#   'know',
#   'that',
#   'the',
#   'freecodecamp',
#   'community',
#   'has',
#   'music',
#   'live',
#   'stream',
#   'called',
#   'code',
#   'radio',
#   'tune',
#   'in',
#   'to',
#   'some',
#   'jazzy',
#   'beats',
#   'while',
#   'you',
#   'code',
#   'live',
#   'stream',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'news',
#   'code',
#   'radio',
#   'nquote',
#   'of',
#   'the',
#   'week',
#   'if',
#   'having',
#   'coffee',
#   'in',
#   'the',
#   'morning',
#   'doesn',
#   'wake',
#   'you',
#   'up',
#   'try',
#   'deleting',
#   'table',
#   'in',
#   'production',
#   'database',
#   'instead',
#   'juozas',
#   'kaziukenas',
#   'nfreecodecamp',
#   'is',
#   'donor',
#   'supported',
#   'nonprofit',
#   'help',
#   'the',
#   'community',
#   'reach',
#   'our',
#   'goal',
#   'of',
#   'monthly',
#   'supporters',
#   'we',
#   're',
#   'already',
#   'of',
#   'the',
#   'way',
#   'there',
#   'become',
#   'supporter',
#   'at',
#   'https',
#   'donate',
#   'freecodecamp',
#   'org',
#   'nhappy',
#   'coding',
#   'quincy',
#   'larson',
#   'nteacher',
#   'at',
#   'freecodecamp',
#   'org',
#   'nif',
#   'these',
#   'emails',
#   'aren',
#   'worth',
#   'your',
#   'time',
#   'you',
#   'can',
#   'turn',
#   'them',
#   'off',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'ue',
#   'ystttlxqo',
#   'nnegosgnvb'],
#  ['here',
#   'are',
#   'this',
#   'week',
#   'five',
#   'links',
#   'that',
#   'are',
#   'worth',
#   'your',
#   'time',
#   'python',
#   'is',
#   'great',
#   'programming',
#   'language',
#   'to',
#   'learn',
#   'once',
#   'you',
#   'feel',
#   'comfortable',
#   'with',
#   'javascript',
#   'here',
#   'harvard',
#   'intro',
#   'to',
#   'python',
#   'hour',
#   'watch',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'news',
#   'learn',
#   'python',
#   'from',
#   'harvards',
#   'cs',
#   'and',
#   'if',
#   'you',
#   'want',
#   'to',
#   'dig',
#   'even',
#   'further',
#   'into',
#   'python',
#   'try',
#   'our',
#   'in',
#   'depth',
#   'course',
#   'on',
#   'python',
#   'basics',
#   'hour',
#   'watch',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'news',
#   'learn',
#   'python',
#   'basics',
#   'in',
#   'depth',
#   'video',
#   'course',
#   'how',
#   'to',
#   'produce',
#   'your',
#   'own',
#   'meaningful',
#   'datasets',
#   'right',
#   'in',
#   'sql',
#   'minute',
#   'read',
#   'https',
#   'medium',
#   'freecodecamp',
#   'org',
#   'ursula',
#   'was',
#   'in',
#   'her',
#   'late',
#   'and',
#   'unhappy',
#   'with',
#   'her',
#   'career',
#   'in',
#   'science',
#   'here',
#   'how',
#   'she',
#   'taught',
#   'herself',
#   'to',
#   'code',
#   'using',
#   'freecodecamp',
#   'for',
#   'months',
#   'then',
#   'got',
#   'job',
#   'as',
#   'developer',
#   'minute',
#   'read',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'forum',
#   'here',
#   'are',
#   'free',
#   'online',
#   'programming',
#   'and',
#   'computer',
#   'science',
#   'courses',
#   'that',
#   'you',
#   'can',
#   'start',
#   'in',
#   'february',
#   'browsable',
#   'list',
#   'https',
#   'medium',
#   'freecodecamp',
#   'org',
#   'nquote',
#   'of',
#   'the',
#   'week',
#   'the',
#   'most',
#   'amazing',
#   'achievement',
#   'of',
#   'the',
#   'computer',
#   'software',
#   'industry',
#   'is',
#   'its',
#   'continuing',
#   'cancellation',
#   'of',
#   'the',
#   'steady',
#   'and',
#   'staggering',
#   'gains',
#   'made',
#   'by',
#   'the',
#   'computer',
#   'hardware',
#   'industry',
#   'henry',
#   'petroski',
#   'nfreecodecamp',
#   'is',
#   'donor',
#   'supported',
#   'nonprofit',
#   'help',
#   'the',
#   'community',
#   'reach',
#   'our',
#   'goal',
#   'of',
#   'monthly',
#   'supporters',
#   'we',
#   're',
#   'already',
#   'of',
#   'the',
#   'way',
#   'there',
#   'become',
#   'supporter',
#   'at',
#   'https',
#   'donate',
#   'freecodecamp',
#   'org',
#   'nhappy',
#   'coding',
#   'quincy',
#   'larson',
#   'nteacher',
#   'at',
#   'freecodecamp',
#   'org',
#   'nif',
#   'these',
#   'emails',
#   'aren',
#   'worth',
#   'your',
#   'time',
#   'you',
#   'can',
#   'turn',
#   'them',
#   'off',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'ue',
#   'ystttlxqo',
#   'nnegosgnvb'],
#  ['here',
#   'are',
#   'this',
#   'week',
#   'five',
#   'links',
#   'that',
#   'are',
#   'worth',
#   'your',
#   'time',
#   'harvard',
#   'cs',
#   'intro',
#   'to',
#   'computer',
#   'science',
#   'course',
#   'is',
#   'now',
#   'free',
#   'and',
#   'ad',
#   'free',
#   'on',
#   'freecodecamp',
#   'youtube',
#   'channel',
#   'we',
#   're',
#   'posting',
#   'one',
#   'new',
#   'video',
#   'each',
#   'day',
#   'and',
#   'discussing',
#   'them',
#   'here',
#   'hour',
#   'course',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'forum',
#   'the',
#   'first',
#   'few',
#   'harvard',
#   'cs',
#   'videos',
#   'are',
#   'now',
#   'live',
#   'capture',
#   'the',
#   'flag',
#   'challenges',
#   'are',
#   'great',
#   'way',
#   'to',
#   'expand',
#   'your',
#   'cybersecurity',
#   'and',
#   'ethical',
#   'hacking',
#   'skills',
#   'here',
#   'an',
#   'in',
#   'depth',
#   'walkthrough',
#   'of',
#   'the',
#   'popular',
#   'picoctf',
#   'challenge',
#   'hour',
#   'tutorial',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'news',
#   'improve',
#   'cybersecurity',
#   'skills',
#   'with',
#   'ctfs',
#   'picoctf',
#   'walkthrough',
#   'how',
#   'graph',
#   'data',
#   'structures',
#   'work',
#   'explained',
#   'visually',
#   'minute',
#   'read',
#   'https',
#   'medium',
#   'freecodecamp',
#   'org',
#   'ec',
#   'how',
#   'to',
#   'build',
#   'your',
#   'own',
#   'first',
#   'person',
#   'shooter',
#   'game',
#   'using',
#   'unity',
#   'hour',
#   'tutorial',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'news',
#   'unity',
#   'first',
#   'person',
#   'shooter',
#   'game',
#   'tutorial',
#   'maribel',
#   'parents',
#   'immigrated',
#   'to',
#   'the',
#   'us',
#   'as',
#   'field',
#   'workers',
#   'she',
#   'was',
#   'the',
#   'first',
#   'person',
#   'in',
#   'her',
#   'family',
#   'to',
#   'graduate',
#   'from',
#   'college',
#   'and',
#   'after',
#   'years',
#   'of',
#   'teaching',
#   'herself',
#   'coding',
#   'she',
#   'is',
#   'now',
#   'working',
#   'as',
#   'software',
#   'engineer',
#   'this',
#   'is',
#   'her',
#   'story',
#   'minute',
#   'read',
#   'https',
#   'medium',
#   'freecodecamp',
#   'org',
#   'ae',
#   'fc',
#   'nthis',
#   'weeks',
#   'quote',
#   'the',
#   'web',
#   'as',
#   'envisaged',
#   'it',
#   'we',
#   'have',
#   'not',
#   'seen',
#   'it',
#   'yet',
#   'the',
#   'future',
#   'is',
#   'still',
#   'so',
#   'much',
#   'bigger',
#   'than',
#   'the',
#   'past',
#   'atim',
#   'berners',
#   'lee',
#   'inventor',
#   'of',
#   'the',
#   'web',
#   'nfreecodecamp',
#   'is',
#   'donor',
#   'supported',
#   'nonprofit',
#   'help',
#   'the',
#   'community',
#   'reach',
#   'our',
#   'goal',
#   'of',
#   'monthly',
#   'supporters',
#   'we',
#   're',
#   'already',
#   'of',
#   'the',
#   'way',
#   'there',
#   'become',
#   'supporter',
#   'at',
#   'https',
#   'donate',
#   'freecodecamp',
#   'org',
#   'nhappy',
#   'coding',
#   'quincy',
#   'larson',
#   'nteacher',
#   'at',
#   'freecodecamp',
#   'org',
#   'nif',
#   'these',
#   'emails',
#   'aren',
#   'worth',
#   'your',
#   'time',
#   'you',
#   'can',
#   'turn',
#   'them',
#   'off',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'ue',
#   'ystttlxqo',
#   'nnegosgnvb'],
#  ['here',
#   'are',
#   'this',
#   'week',
#   'five',
#   'links',
#   'that',
#   'are',
#   'worth',
#   'your',
#   'time',
#   'how',
#   'to',
#   'build',
#   'your',
#   'own',
#   'commerce',
#   'website',
#   'from',
#   'scratch',
#   'with',
#   'react',
#   'and',
#   'how',
#   'to',
#   'host',
#   'it',
#   'for',
#   'free',
#   'using',
#   'netlify',
#   'hour',
#   'watch',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'news',
#   'react',
#   'tutorial',
#   'ecomerce',
#   'site',
#   'here',
#   'are',
#   'ivy',
#   'league',
#   'courses',
#   'you',
#   'can',
#   'take',
#   'online',
#   'right',
#   'now',
#   'for',
#   'free',
#   'browsable',
#   'list',
#   'https',
#   'medium',
#   'freecodecamp',
#   'org',
#   'ffcbd',
#   'how',
#   'to',
#   'design',
#   'website',
#   'layouts',
#   'that',
#   'work',
#   'well',
#   'with',
#   'screen',
#   'readers',
#   'so',
#   'that',
#   'blind',
#   'people',
#   'can',
#   'use',
#   'your',
#   'website',
#   'too',
#   'minute',
#   'read',
#   'https',
#   'medium',
#   'freecodecamp',
#   'org',
#   'cc',
#   'the',
#   'story',
#   'of',
#   'how',
#   'vivian',
#   'went',
#   'from',
#   'working',
#   'in',
#   'nigerian',
#   'call',
#   'center',
#   'to',
#   'landing',
#   'her',
#   'first',
#   'job',
#   'as',
#   'software',
#   'developer',
#   'she',
#   'used',
#   'freecodecamp',
#   'and',
#   'took',
#   'the',
#   'days',
#   'of',
#   'code',
#   'challenge',
#   'minute',
#   'read',
#   'https',
#   'medium',
#   'freecodecamp',
#   'org',
#   'bca',
#   'introducing',
#   'you',
#   'can',
#   'do',
#   'this',
#   'new',
#   'place',
#   'where',
#   'you',
#   'can',
#   'get',
#   'support',
#   'during',
#   'your',
#   'coding',
#   'journey',
#   'minute',
#   'read',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'news',
#   'you',
#   'can',
#   'do',
#   'this',
#   'nthis',
#   'week',
#   'quote',
#   'we',
#   'can',
#   'only',
#   'see',
#   'short',
#   'distance',
#   'ahead',
#   'but',
#   'we',
#   'can',
#   'see',
#   'plenty',
#   'there',
#   'that',
#   'needs',
#   'to',
#   'be',
#   'done',
#   'aalan',
#   'turing',
#   'na',
#   'huge',
#   'thanks',
#   'to',
#   'the',
#   'supporters',
#   'who',
#   'donate',
#   'to',
#   'our',
#   'nonprofit',
#   'each',
#   'month',
#   'you',
#   'make',
#   'all',
#   'of',
#   'this',
#   'possible',
#   'if',
#   'you',
#   're',
#   'not',
#   'donating',
#   'yet',
#   'please',
#   'consider',
#   'doing',
#   'so',
#   'https',
#   'donate',
#   'freecodecamp',
#   'org',
#   'nhappy',
#   'coding',
#   'quincy',
#   'larson',
#   'nteacher',
#   'at',
#   'freecodecamp',
#   'org',
#   'nif',
#   'these',
#   'emails',
#   'aren',
#   'worth',
#   'your',
#   'time',
#   'you',
#   'can',
#   'turn',
#   'them',
#   'off',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'ue',
#   'ystttlxqo',
#   'nnegosgnvb'],
#  ['here',
#   'are',
#   'this',
#   'week',
#   'five',
#   'links',
#   'that',
#   'are',
#   'worth',
#   'your',
#   'time',
#   'the',
#   'react',
#   'handbook',
#   'massive',
#   'free',
#   'guide',
#   'to',
#   'building',
#   'web',
#   'applications',
#   'with',
#   'reactjs',
#   'minute',
#   'read',
#   'https',
#   'medium',
#   'freecodecamp',
#   'org',
#   'the',
#   'react',
#   'handbook',
#   'how',
#   'to',
#   'build',
#   'your',
#   'own',
#   'tetris',
#   'game',
#   'using',
#   'python',
#   'and',
#   'pygame',
#   'hour',
#   'watch',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'news',
#   'tetris',
#   'python',
#   'tutorial',
#   'pygame',
#   'the',
#   'story',
#   'of',
#   'how',
#   'christina',
#   'went',
#   'from',
#   'stay',
#   'at',
#   'home',
#   'mother',
#   'of',
#   'kids',
#   'to',
#   'working',
#   'full',
#   'time',
#   'from',
#   'home',
#   'as',
#   'javascript',
#   'developer',
#   'minute',
#   'read',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'forum',
#   'learn',
#   'mongodb',
#   'the',
#   'popular',
#   'nosql',
#   'database',
#   'by',
#   'building',
#   'node',
#   'js',
#   'crud',
#   'app',
#   'from',
#   'scratch',
#   'minute',
#   'watch',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'news',
#   'mongodb',
#   'crud',
#   'app',
#   'over',
#   'the',
#   'winter',
#   'holiday',
#   'angela',
#   'challenged',
#   'herself',
#   'to',
#   'build',
#   'one',
#   'coding',
#   'project',
#   'each',
#   'day',
#   'for',
#   'days',
#   'her',
#   'resulting',
#   'apps',
#   'are',
#   'fun',
#   'and',
#   'elegant',
#   'minute',
#   'read',
#   'https',
#   'medium',
#   'freecodecamp',
#   'org',
#   'cd',
#   'nthis',
#   'week',
#   'quote',
#   'if',
#   'the',
#   'automobile',
#   'had',
#   'followed',
#   'the',
#   'same',
#   'development',
#   'cycle',
#   'as',
#   'the',
#   'computer',
#   'rolls',
#   'royce',
#   'would',
#   'today',
#   'cost',
#   'get',
#   'million',
#   'miles',
#   'per',
#   'gallon',
#   'and',
#   'explode',
#   'once',
#   'year',
#   'killing',
#   'everyone',
#   'inside',
#   'robert',
#   'cringely',
#   'nfreecodecamp',
#   'org',
#   'is',
#   'nonprofit',
#   'huge',
#   'thanks',
#   'to',
#   'our',
#   'supporters',
#   'who',
#   'donate',
#   'each',
#   'month',
#   'to',
#   'make',
#   'all',
#   'of',
#   'this',
#   'possible',
#   'for',
#   'less',
#   'than',
#   'the',
#   'price',
#   'of',
#   'sandwich',
#   'you',
#   'can',
#   'support',
#   'us',
#   'too',
#   'https',
#   'donate',
#   'freecodecamp',
#   'org',
#   'nhappy',
#   'coding',
#   'quincy',
#   'larson',
#   'nteacher',
#   'at',
#   'freecodecamp',
#   'org',
#   'nif',
#   'these',
#   'emails',
#   'aren',
#   'worth',
#   'your',
#   'time',
#   'you',
#   'can',
#   'turn',
#   'them',
#   'off',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'ue',
#   'ystttlxqo',
#   'nnegosgnvb'],
#  ['this',
#   'is',
#   'my',
#   'final',
#   'links',
#   'worth',
#   'your',
#   'time',
#   'list',
#   'for',
#   'happy',
#   'holidays',
#   'nhere',
#   'are',
#   'this',
#   'week',
#   'five',
#   'links',
#   'that',
#   'are',
#   'worth',
#   'your',
#   'time',
#   'learn',
#   'react',
#   'js',
#   'with',
#   'this',
#   'free',
#   'hour',
#   'course',
#   'for',
#   'beginners',
#   'you',
#   'll',
#   'learn',
#   'about',
#   'styling',
#   'components',
#   'conditional',
#   'rendering',
#   'state',
#   'management',
#   'and',
#   'more',
#   'hour',
#   'watch',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'jilknpplm',
#   'introducing',
#   'programmer',
#   'playing',
#   'cards',
#   'learn',
#   'about',
#   'programmer',
#   'history',
#   'while',
#   'you',
#   'play',
#   'classic',
#   'card',
#   'games',
#   'like',
#   'poker',
#   'blackjack',
#   'and',
#   'solitaire',
#   'minute',
#   'read',
#   'https',
#   'medium',
#   'freecodecamp',
#   'org',
#   'eeeffe',
#   'here',
#   'are',
#   'the',
#   'results',
#   'of',
#   'the',
#   'freecodecamp',
#   'new',
#   'coder',
#   'survey',
#   'respondents',
#   'told',
#   'us',
#   'about',
#   'how',
#   'they',
#   're',
#   'learning',
#   'to',
#   'code',
#   'and',
#   'getting',
#   'their',
#   'first',
#   'developer',
#   'jobs',
#   'minute',
#   'read',
#   'https',
#   'medium',
#   'freecodecamp',
#   'org',
#   'feb',
#   'ed',
#   'learn',
#   'how',
#   'to',
#   'build',
#   'your',
#   'own',
#   'android',
#   'app',
#   'this',
#   'free',
#   'course',
#   'will',
#   'show',
#   'you',
#   'how',
#   'to',
#   'use',
#   'android',
#   'studio',
#   'firebase',
#   'java',
#   'and',
#   'more',
#   'to',
#   'build',
#   'your',
#   'own',
#   'clone',
#   'of',
#   'whatsapp',
#   'messenger',
#   'hour',
#   'watch',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'kslpiub',
#   'how',
#   'phoebe',
#   'went',
#   'from',
#   'stay',
#   'at',
#   'home',
#   'mom',
#   'to',
#   'working',
#   'as',
#   'front',
#   'end',
#   'web',
#   'developer',
#   'in',
#   'less',
#   'than',
#   'year',
#   'by',
#   'studying',
#   'freecodecamp',
#   'minute',
#   'read',
#   'https',
#   'medium',
#   'freecodecamp',
#   'org',
#   'nhappy',
#   'coding',
#   'quincy',
#   'larson',
#   'nteacher',
#   'at',
#   'freecodecamp',
#   'org',
#   'nif',
#   'these',
#   'emails',
#   'aren',
#   'worth',
#   'your',
#   'time',
#   'you',
#   'can',
#   'turn',
#   'them',
#   'off',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'ue',
#   'ystttlxqo',
#   'nnegosgnvb'],
#  ['here',
#   'are',
#   'this',
#   'week',
#   'five',
#   'links',
#   'that',
#   'are',
#   'worth',
#   'your',
#   'time',
#   'learn',
#   'javascript',
#   'our',
#   'free',
#   'part',
#   'video',
#   'course',
#   'for',
#   'beginners',
#   'hour',
#   'watch',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'va',
#   'cr',
#   'learn',
#   'penetration',
#   'testing',
#   'from',
#   'beginner',
#   'to',
#   'advanced',
#   'we',
#   'cover',
#   'ethical',
#   'hacking',
#   'concepts',
#   'like',
#   'csrf',
#   'xss',
#   'brute',
#   'force',
#   'attacks',
#   'sql',
#   'injection',
#   'and',
#   'more',
#   'in',
#   'this',
#   'free',
#   'video',
#   'course',
#   'hour',
#   'watch',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'pena',
#   'cr',
#   'amazingly',
#   'out',
#   'of',
#   'every',
#   'developers',
#   'is',
#   'completely',
#   'blind',
#   'here',
#   'how',
#   'freecodecamp',
#   'is',
#   'helping',
#   'teach',
#   'even',
#   'more',
#   'blind',
#   'people',
#   'how',
#   'to',
#   'code',
#   'minute',
#   'read',
#   'https',
#   'medium',
#   'freecodecamp',
#   'org',
#   'even',
#   'in',
#   'an',
#   'active',
#   'war',
#   'zones',
#   'in',
#   'afghanistan',
#   'thousands',
#   'of',
#   'people',
#   'are',
#   'coming',
#   'together',
#   'to',
#   'learn',
#   'to',
#   'code',
#   'and',
#   'expand',
#   'their',
#   'careers',
#   'using',
#   'freecodecamp',
#   'minute',
#   'read',
#   'https',
#   'medium',
#   'freecodecamp',
#   'org',
#   'here',
#   'are',
#   'free',
#   'online',
#   'programming',
#   'and',
#   'computer',
#   'science',
#   'courses',
#   'you',
#   'can',
#   'start',
#   'in',
#   'december',
#   'browsable',
#   'list',
#   'https',
#   'medium',
#   'freecodecamp',
#   'org',
#   'ac',
#   'de',
#   'nfreecodecamp',
#   'is',
#   'tiny',
#   'nonprofit',
#   'with',
#   'big',
#   'mission',
#   'to',
#   'provide',
#   'everyone',
#   'with',
#   'world',
#   'class',
#   'technology',
#   'education',
#   'for',
#   'free',
#   'your',
#   'tax',
#   'deductible',
#   'donations',
#   'help',
#   'us',
#   'create',
#   'more',
#   'learning',
#   'tools',
#   'and',
#   'resources',
#   'become',
#   'supporter',
#   'today',
#   'at',
#   'https',
#   'donate',
#   'freecodecamp',
#   'org',
#   'nhappy',
#   'coding',
#   'quincy',
#   'larson',
#   'nteacher',
#   'at',
#   'freecodecamp',
#   'org',
#   'nif',
#   'these',
#   'emails',
#   'aren',
#   'worth',
#   'your',
#   'time',
#   'you',
#   'can',
#   'turn',
#   'them',
#   'off',
#   'https',
#   'www',
#   'freecodecamp',
#   'org',
#   'ue',
#   'ystttlxqo',
#   'nnegosgnvb']]

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization

nlp = spacy.load("en_core_web_sm",disable=['parser', 'ner']) 
 
# Adding additional stopwords
new_stopwords= ['dear', 'thanks','regards', 'hello','hi', 'bye','goodbye', 'say', 'https',  'www', 'freecodecamp', 'org', 'news', 'five', 'links', 'worth', 'time', 'teach', 'read', 'email', 'week', 'minute', 'twitter', 'learn', 'course', 'quincy', 'larson', 'code', 'happy', 'ystttlxqo', 'nnegosgnvb', 'donate', 'build', 'teacher', 'hour', 'start', 'free', 'new', 'thing', 'use', 'tip']

for word in new_stopwords:
    nlp.Defaults.stop_words.add(word) 
    nlp.vocab[word].is_stop = True
    
def remove_stopwords_spacy(texts):
    return [[word.text for word in nlp(str(text)) if not word.is_stop] for text in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append(" ".join([token.lemma_ if token.lemma_ not in ['-PRON-'] else '' for           token in doc if token.pos_ in allowed_postags]))
    return texts_out
# Out:
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# # Remove Stop Words
#data_words_nostops = remove_stopwords_spacy(data_words)

# #remove words that only occur once to make process faster
# #all_tokens = sum(data_words_nostops, [])
# #tokens_once = set(word for word in set(all_tokens) if all_tokens.count(word) == 1)
# #text_no_single_words = [[term for term in words if term not in tokens_once] for words in data_words_nostops]

#data_vocab_words=remove_non_vocab(data_words_nostops)

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_nostops, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
# Out:
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(data_lemmatized[0])
# Out:
# building video game fun play depth unity beginner start game developer install unity program game physics animate character enemy ai youtube game development beginner unity website wordpress relatively easy tool building blog ecommerce site elaborate application host wordpress site web add custom feature plugin design look want youtube website wordpress hear branch science call game theory tutorial evolutionary game theory work ecosystem simulation python good old fashion math introduction evolutionary game theory kubernete powerful devop tool manage software cloud haven hear year old say search find job opening mention kubernete lot company sergio recently pass linux foundation exam certify kubernete application developer share tip certify kubernete application developer dhawal update massive list course ivy league university online browsable list ivy league online course nand quick update make steady progress datum science curriculum expansion certification advanced mathematic computer science machine learn far people donate ensure nonprofit budget need hire experienced teacher involve building datum science curriculum advanced math machine learn nquote obsess finish skill year ve realize good thing come way able finish start derek game developer creator spelunky nhappy code nteacher share useful thing com ossia email aren turn
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Create Document-Word matrix

vectorizer = CountVectorizer(analyzer='word',       
                             min_df=1, # minimum required occurences of a word 
                             max_df=0.15, # maximum required occurences of a word
                             stop_words='english', # remove stop words
                             lowercase=True, # convert all words to lowercase
                             token_pattern='[a-zA-Z0-9]{3,}', # num chars > 3
                             # max_features=50000,  # max number of uniq words
                             )
# Out:
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data_vectorized = vectorizer.fit_transform(data_lemmatized)
# Out:
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Build LDA Model with SK learn
# Build LDA Model
lda_model = LatentDirichletAllocation(n_components=5,# Number of topics
                                      max_iter=10,    # Max learning iterations
                                      learning_method='online',   
                                      random_state=100, # Random state
                                      batch_size=100,   # n docs in each learning iter
                                      evaluate_every = -1, # compute perplexity every n iters, default: Don't
                                      n_jobs = -1,        # Use all available CPUs
                                      total_samples=1000000.0
                                     )

lda_output = lda_model.fit_transform(data_vectorized)
print(lda_model)  # Model attributes
# Out:
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# LatentDirichletAllocation(batch_size=100, learning_method='online',
#                           n_components=5, n_jobs=-1, random_state=100)

# %%
# Log Likelihood: Higher the better
print("Log Likelihood: ", lda_model.score(data_vectorized))
# Perplexity: Lower the better. Perplexity = exp(-1. * log-likelihood per word)
print("Perplexity: ", lda_model.perplexity(data_vectorized))
# See model parameters
pprint(lda_model.get_params())
# Out:
# Log Likelihood:  -51544.01773784743
# Perplexity:  3157.480689985695
# {'batch_size': 100,
#  'doc_topic_prior': None,
#  'evaluate_every': -1,
#  'learning_decay': 0.7,
#  'learning_method': 'online',
#  'learning_offset': 10.0,
#  'max_doc_update_iter': 100,
#  'max_iter': 10,
#  'mean_change_tol': 0.001,
#  'n_components': 5,
#  'n_jobs': -1,
#  'perp_tol': 0.1,
#  'random_state': 100,
#  'topic_word_prior': None,
#  'total_samples': 1000000.0,
#  'verbose': 0}
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Define Search Param
search_params = {'n_components': [3, 5, 7, 8], 'learning_decay': [.5, .7, .9]}

# Init the Model
lda = LatentDirichletAllocation(max_iter=5, learning_method='online', learning_offset=50.,random_state=0)

# Init Grid Search Class
model = GridSearchCV(lda, param_grid=search_params)

# Do the Grid Search
model.fit(data_vectorized)
# Out:
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# GridSearchCV(estimator=LatentDirichletAllocation(learning_method='online',
#                                                  learning_offset=50.0,
#                                                  max_iter=5, random_state=0),
#              param_grid={'learning_decay': [0.5, 0.7, 0.9],
#                          'n_components': [3, 5, 7, 8]})

# %%
# Best Model
best_lda_model = model.best_estimator_
# Model Parameters
print("Best Model's Params: ", model.best_params_)
# Log Likelihood Score
print("Best Log Likelihood Score: ", model.best_score_)
# Perplexity
print("Model Perplexity: ", best_lda_model.perplexity(data_vectorized))
# Out:
# Best Model's Params:  {'learning_decay': 0.7, 'n_components': 3}
# Best Log Likelihood Score:  -12442.527718489535
# Model Perplexity:  3161.2229182668434
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Create Document — Topic Matrix
lda_output = best_lda_model.transform(data_vectorized)
# column names
topicnames = ["Topic" + str(i) for i in range(best_lda_model.n_components)]
# index names
docnames = ["Doc" + str(i) for i in range(len(data))]
# Make the pandas dataframe
df_document_topic = pd.DataFrame(np.round(lda_output, 2), columns=topicnames, index=docnames)
# Get dominant topic for each document
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic['dominant_topic'] = dominant_topic
# Styling
def color_green(val):
 color = 'green' if val > .1 else 'black'
 return 'color: {col}'.format(col=color)
def make_bold(val):
 weight = 700 if val > .1 else 400
 return 'font-weight: {weight}'.format(weight=weight)
# Apply Style
df_document_topics = df_document_topic.head(15).style.applymap(color_green).applymap(make_bold)
df_document_topics
# Out:
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <style  type="text/css" >
# #T_cdf93_row0_col0,#T_cdf93_row0_col1,#T_cdf93_row1_col1,#T_cdf93_row1_col2,#T_cdf93_row1_col3,#T_cdf93_row2_col0,#T_cdf93_row2_col1,#T_cdf93_row3_col1,#T_cdf93_row3_col2,#T_cdf93_row3_col3,#T_cdf93_row4_col0,#T_cdf93_row4_col2,#T_cdf93_row5_col1,#T_cdf93_row5_col2,#T_cdf93_row5_col3,#T_cdf93_row6_col1,#T_cdf93_row6_col2,#T_cdf93_row6_col3,#T_cdf93_row7_col0,#T_cdf93_row7_col1,#T_cdf93_row8_col0,#T_cdf93_row8_col2,#T_cdf93_row9_col0,#T_cdf93_row9_col2,#T_cdf93_row10_col0,#T_cdf93_row10_col2,#T_cdf93_row11_col0,#T_cdf93_row11_col1,#T_cdf93_row12_col0,#T_cdf93_row12_col2,#T_cdf93_row13_col0,#T_cdf93_row13_col2,#T_cdf93_row14_col0,#T_cdf93_row14_col2{
#             color:  black;
#             font-weight:  400;
#         }#T_cdf93_row0_col2,#T_cdf93_row0_col3,#T_cdf93_row1_col0,#T_cdf93_row2_col2,#T_cdf93_row2_col3,#T_cdf93_row3_col0,#T_cdf93_row4_col1,#T_cdf93_row4_col3,#T_cdf93_row5_col0,#T_cdf93_row6_col0,#T_cdf93_row7_col2,#T_cdf93_row7_col3,#T_cdf93_row8_col1,#T_cdf93_row8_col3,#T_cdf93_row9_col1,#T_cdf93_row9_col3,#T_cdf93_row10_col1,#T_cdf93_row10_col3,#T_cdf93_row11_col2,#T_cdf93_row11_col3,#T_cdf93_row12_col1,#T_cdf93_row12_col3,#T_cdf93_row13_col1,#T_cdf93_row13_col3,#T_cdf93_row14_col1,#T_cdf93_row14_col3{
#             color:  green;
#             font-weight:  700;
#         }</style><table id="T_cdf93_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Topic0</th>        <th class="col_heading level0 col1" >Topic1</th>        <th class="col_heading level0 col2" >Topic2</th>        <th class="col_heading level0 col3" >dominant_topic</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cdf93_level0_row0" class="row_heading level0 row0" >Doc0</th>
#                         <td id="T_cdf93_row0_col0" class="data row0 col0" >0.000000</td>
#                         <td id="T_cdf93_row0_col1" class="data row0 col1" >0.000000</td>
#                         <td id="T_cdf93_row0_col2" class="data row0 col2" >0.990000</td>
#                         <td id="T_cdf93_row0_col3" class="data row0 col3" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_cdf93_level0_row1" class="row_heading level0 row1" >Doc1</th>
#                         <td id="T_cdf93_row1_col0" class="data row1 col0" >0.990000</td>
#                         <td id="T_cdf93_row1_col1" class="data row1 col1" >0.000000</td>
#                         <td id="T_cdf93_row1_col2" class="data row1 col2" >0.000000</td>
#                         <td id="T_cdf93_row1_col3" class="data row1 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_cdf93_level0_row2" class="row_heading level0 row2" >Doc2</th>
#                         <td id="T_cdf93_row2_col0" class="data row2 col0" >0.000000</td>
#                         <td id="T_cdf93_row2_col1" class="data row2 col1" >0.000000</td>
#                         <td id="T_cdf93_row2_col2" class="data row2 col2" >0.990000</td>
#                         <td id="T_cdf93_row2_col3" class="data row2 col3" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_cdf93_level0_row3" class="row_heading level0 row3" >Doc3</th>
#                         <td id="T_cdf93_row3_col0" class="data row3 col0" >0.990000</td>
#                         <td id="T_cdf93_row3_col1" class="data row3 col1" >0.000000</td>
#                         <td id="T_cdf93_row3_col2" class="data row3 col2" >0.000000</td>
#                         <td id="T_cdf93_row3_col3" class="data row3 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_cdf93_level0_row4" class="row_heading level0 row4" >Doc4</th>
#                         <td id="T_cdf93_row4_col0" class="data row4 col0" >0.000000</td>
#                         <td id="T_cdf93_row4_col1" class="data row4 col1" >0.990000</td>
#                         <td id="T_cdf93_row4_col2" class="data row4 col2" >0.000000</td>
#                         <td id="T_cdf93_row4_col3" class="data row4 col3" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_cdf93_level0_row5" class="row_heading level0 row5" >Doc5</th>
#                         <td id="T_cdf93_row5_col0" class="data row5 col0" >0.990000</td>
#                         <td id="T_cdf93_row5_col1" class="data row5 col1" >0.000000</td>
#                         <td id="T_cdf93_row5_col2" class="data row5 col2" >0.000000</td>
#                         <td id="T_cdf93_row5_col3" class="data row5 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_cdf93_level0_row6" class="row_heading level0 row6" >Doc6</th>
#                         <td id="T_cdf93_row6_col0" class="data row6 col0" >0.990000</td>
#                         <td id="T_cdf93_row6_col1" class="data row6 col1" >0.000000</td>
#                         <td id="T_cdf93_row6_col2" class="data row6 col2" >0.000000</td>
#                         <td id="T_cdf93_row6_col3" class="data row6 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_cdf93_level0_row7" class="row_heading level0 row7" >Doc7</th>
#                         <td id="T_cdf93_row7_col0" class="data row7 col0" >0.010000</td>
#                         <td id="T_cdf93_row7_col1" class="data row7 col1" >0.010000</td>
#                         <td id="T_cdf93_row7_col2" class="data row7 col2" >0.990000</td>
#                         <td id="T_cdf93_row7_col3" class="data row7 col3" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_cdf93_level0_row8" class="row_heading level0 row8" >Doc8</th>
#                         <td id="T_cdf93_row8_col0" class="data row8 col0" >0.010000</td>
#                         <td id="T_cdf93_row8_col1" class="data row8 col1" >0.990000</td>
#                         <td id="T_cdf93_row8_col2" class="data row8 col2" >0.010000</td>
#                         <td id="T_cdf93_row8_col3" class="data row8 col3" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_cdf93_level0_row9" class="row_heading level0 row9" >Doc9</th>
#                         <td id="T_cdf93_row9_col0" class="data row9 col0" >0.010000</td>
#                         <td id="T_cdf93_row9_col1" class="data row9 col1" >0.990000</td>
#                         <td id="T_cdf93_row9_col2" class="data row9 col2" >0.010000</td>
#                         <td id="T_cdf93_row9_col3" class="data row9 col3" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_cdf93_level0_row10" class="row_heading level0 row10" >Doc10</th>
#                         <td id="T_cdf93_row10_col0" class="data row10 col0" >0.010000</td>
#                         <td id="T_cdf93_row10_col1" class="data row10 col1" >0.990000</td>
#                         <td id="T_cdf93_row10_col2" class="data row10 col2" >0.010000</td>
#                         <td id="T_cdf93_row10_col3" class="data row10 col3" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_cdf93_level0_row11" class="row_heading level0 row11" >Doc11</th>
#                         <td id="T_cdf93_row11_col0" class="data row11 col0" >0.010000</td>
#                         <td id="T_cdf93_row11_col1" class="data row11 col1" >0.010000</td>
#                         <td id="T_cdf93_row11_col2" class="data row11 col2" >0.990000</td>
#                         <td id="T_cdf93_row11_col3" class="data row11 col3" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_cdf93_level0_row12" class="row_heading level0 row12" >Doc12</th>
#                         <td id="T_cdf93_row12_col0" class="data row12 col0" >0.000000</td>
#                         <td id="T_cdf93_row12_col1" class="data row12 col1" >0.990000</td>
#                         <td id="T_cdf93_row12_col2" class="data row12 col2" >0.000000</td>
#                         <td id="T_cdf93_row12_col3" class="data row12 col3" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_cdf93_lev

# %%
# Show top n keywords for each topic
def show_topics(vectorizer=vectorizer, lda_model=lda_model, n_words=20):
    keywords = np.array(vectorizer.get_feature_names())
    topic_keywords = []
    for topic_weights in lda_model.components_:
        top_keyword_locs = (-topic_weights).argsort()[:n_words]
        topic_keywords.append(keywords.take(top_keyword_locs))
    return topic_keywords
topic_keywords = show_topics(vectorizer=vectorizer, lda_model=best_lda_model, n_words=10)
# Topic - Keywords Dataframe
df_topic_keywords = pd.DataFrame(topic_keywords)
df_topic_keywords.columns = ['Word '+str(i) for i in range(df_topic_keywords.shape[1])]
df_topic_keywords.index = ['Topic '+str(i) for i in range(df_topic_keywords.shape[0])]
df_topic_keywords
# Out:
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#              Word 0   Word 1     Word 2  Word 3 Word 4   Word 5      Word 6  \
# Topic 0  curriculum  testing       hire     day    tax   visual  serverless
# Topic 1     network      day  algorithm  google    css  command         sql
# Topic 2         api     html        css    step   look   career    security
#
#              Word 7      Word 8      Word 9
# Topic 0        hook  deductible  experience
# Topic 1     english        deep   challenge
# Topic 2  conference        home    complete

# %%
Topics = ["Cloud","Programming/Machine Learning","Career/Work"]
df_topic_keywords["Topics"]=Topics
df_topic_keywords
# Out:
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#              Word 0   Word 1     Word 2  Word 3 Word 4   Word 5      Word 6  \
# Topic 0  curriculum  testing       hire     day    tax   visual  serverless
# Topic 1     network      day  algorithm  google    css  command         sql
# Topic 2         api     html        css    step   look   career    security
#
#              Word 7      Word 8      Word 9                        Topics
# Topic 0        hook  deductible  experience                         Cloud
# Topic 1     english        deep   challenge  Programming/Machine Learning
# Topic 2  conference        home    complete                   Career/Work

# %%
# Define function to predict topic for a given text document.
#nlp = spacy.load('en', disable=['parser', 'ner'])

def predict_topic(text, nlp=nlp):
    global sent_to_words
    global lemmatization
# Step 1: Clean with simple_preprocess
    mytext_2 = list(sent_to_words(text))
# Step 2: Lemmatize
    mytext_3 = lemmatization(mytext_2, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
# Step 3: Vectorize transform
    mytext_4 = vectorizer.transform(mytext_3)
# Step 4: LDA Transform
    topic_probability_scores = best_lda_model.transform(mytext_4)
    topic = df_topic_keywords.iloc[np.argmax(topic_probability_scores), 1:14].values.tolist()
    
    # Step 5: Infer Topic
    infer_topic = df_topic_keywords.iloc[np.argmax(topic_probability_scores), -1]
    
    #topic_guess = df_topic_keywords.iloc[np.argmax(topic_probability_scores), Topics]
    return infer_topic, topic, topic_probability_scores

# Predict the topic
mytext = ["Here are this week's five links that are worth your time: \
1. If you used the internet today, you probably used NGINX. It's a powerful web server that most major websites use to handle traffic. And freeCodeCamp just published a free full-length NGINX book that will show you how to use this web server tool for routing, reverse proxying, and even load balancing. (2 hour read): https://www.freecodecamp.org/news/the-nginx-handbook/ \
2. You can also learn the MERN Stack by building your own Yelp-like restaurant review site. MERN stands for MongoDB + Express + React + Node.js. Then in the second half of the course, you'll learn how to swap out your Node.js/Express back end in favor of Serverless Architecture. (3 hour YouTube course): https://www.freecodecamp.org/news/create-a-mern-stack-app-with-a-serverless-backend/\
3. Learn how to create your own 3D graphics using OpenGL. You'll work with polygons, textures, shaders, and other important rendering tools. (2 hour YouTube course): https://www.freecodecamp.org/news/how-to-create-3d-and-2d-graphics-with-opengl-and-cpp/\
4. If you're learning Python, I encourage you to bookmark this. Prolific teacher and developer Estefania walks you through dozens of Python syntax examples that all beginners should learn. Data structures, loops, exception handling, dependency inclusion – everything. (90 minute read): https://www.freecodecamp.org/news/python-code-examples-sample-script-coding-tutorial-for-beginners/\
5. And while you're expanding your Python skills, you can learn how to do back end web development using the popular Python Django framework. You'll build data visualization web apps using Pandas dataframes, Matplotlib, and Seaborn. You'll also work with PDF rendering and even base-64 encoding. (7 hour YouTube course): https://www.freecodecamp.org/news/learn-django-3-and-start-creating-websites-with-python/\
Finally, a quick update on freeCodeCamp's Data Science Curriculum Expansion. We're designing 12 new certifications that will teach advanced mathematics, computer science, and machine learning. So far 2,031 people have donated to ensure that our nonprofit has a big enough budget to hire experienced teachers. You can learn more and get involved here: https://www.freecodecamp.org/news/building-a-data-science-curriculum-with-advanced-math-and-machine-learning/\
Quote of the Week: “Anytime someone builds a little application that runs on a cell phone, there's something that goes on the server.” – James Gosling, creator of the Java programming language\
Happy coding.\
- Quincy Larson \
Teacher at https://www.freecodecamp.org\
I share useful things on Twitter at https://www.twitter.com/ossia \
If these emails aren't worth your time, you can turn them off: https://www.freecodecamp.org/ue/YSTttLxqo1nneGosGnvB"] 

infer_topic, topic, prob_scores = predict_topic(text = mytext)
print(topic)
print(infer_topic)
# Out:
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['day', 'algorithm', 'google', 'css', 'command', 'sql', 'english', 'deep', 'challenge', 'Programming/Machine Learning']
# Programming/Machine Learning

# %%
def apply_predict_topic(text):
 text = [text]
 infer_topic, topic, prob_scores = predict_topic(text = text)
 return(infer_topic)

email_dataset["Topic_key_word"]= email_dataset['Message_body'].apply(apply_predict_topic)
email_dataset
# Out:
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                      Date_time                                     From  \
# 0    2021-04-16 11:34:34+00:00  Quincy Larson <quincy@freecodecamp.org>
# 1    2021-04-09 19:15:54+00:00  Quincy Larson <quincy@freecodecamp.org>
# 2    2021-04-02 14:59:32+00:00  Quincy Larson <quincy@freecodecamp.org>
# 3    2021-03-26 17:00:08+00:00  Quincy Larson <quincy@freecodecamp.org>
# 4    2021-03-05 14:37:38+00:00  Quincy Larson <quincy@freecodecamp.org>
# ..                         ...                                      ...
# 99   2019-01-25 05:45:19+00:00  Quincy Larson <quincy@freecodecamp.org>
# 100  2019-01-17 17:45:13+00:00  Quincy Larson <quincy@freecodecamp.org>
# 101  2019-01-10 17:19:18+00:00  Quincy Larson <quincy@freecodecamp.org>
# 102  2018-12-20 22:09:04+00:00  Quincy Larson <quincy@freecodecamp.org>
# 103  2018-12-13 12:25:58+00:00  Quincy Larson <quincy@freecodecamp.org>
#
#                       To                                            Subject  \
# 0    malvisbid@gmail.com  Learn how to code video games [free 7-hour Uni...
# 1    malvisbid@gmail.com  Two free Python courses for you this week – Dj...
# 2    malvisbid@gmail.com  Learn to code APIs using Node.js [free 8-hour ...
# 3    malvisbid@gmail.com  40 JavaScript project ideas so you can learn b...
# 4    malvisbid@gmail.com  Learn AWS cloud basics [free 5-hour DevOps cou...
# ..                   ...                                                ...
# 99   malvisbid@gmail.com  Harvard's CS50 Intro to Computer Science cours...
# 100  malvisbid@gmail.com  How to build your own e-commerce website from ...
# 101  malvisbid@gmail.com  The React Handbook - a massive free guide to b...
# 102  malvisbid@gmail.com  Learn React.js - a free 5-hour course for begi...
# 103  malvisbid@gmail.com  Learn JavaScript - our free 134-part video cou...
#
#                                           Message_body  \
# 0    Here are this week's five links that are worth...
# 1    Here are this week's five links that are worth...
# 2    Here are this week's five links that are worth...
# 3    Here are this week's five links that are worth...
# 4    Here are this week's five links that are worth...
# ..                                                 ...
# 99   Here are this week's five links that are worth...
# 100  Here are this week's five links that are worth...
# 101  Here are this week's five links that are worth...
# 102  This is my final "links worth your time" list ...
# 103  Here are this week's five links that are worth...
#
#                    Topic_key_word
# 0                     Career/Work
# 1                           Cloud
# 2                     Career/Work
# 3                           Cloud
# 4    Programming/Machine Learning
# ..                            ...
# 99   Programming/Machine Learning
# 100  Programming/Machine Learning
# 101                   Career/Work
# 102                   Career/Work
# 103                         Cloud
#
# [104 rows x 6 columns]

# %%
email_dataset.groupby('Topic_key_word').nunique()
# Out:
# d:\Malvi's Files\Malvi Bid\Nottingham Modules\SE Group Project\Software\Intelligent Email\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                               Date_time  From  To  Subject  Message_body
# Topic_key_word
# Career/Work                          38     1   1       38            38
# Cloud                                18     1   1       18            18
# Programming/Machine Learning         48     2   1       48            48
